# %% [markdown]
# # Data Preparation And Cleaning
# This dataset is from THE WORLD BANK
# It is used to show the amounts of money used in each African country in depending on the tye of Loan, Credits, Bonds and Grants over the years in the month of January.The analysis is to show the Relationship and gather insights and probable trends after cleaning the dataset.
#
#  1. Load the file using Pandas
#  2. Fix any missing or incorrect values
#  3. Analyse the data and using graphs to give an overview of the trends and insights

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
#Get the dataset

df = pd.read_excel("AfricaDataset/AfricanEconomic-2019JanuaryState.xlsx")
df
# Out:
#      Country_and_Regions            Country  RegionId             Indicators  \
# 0                    DZA             Algeria       DZ      NY.GDP.MKTP.KD.ZG
# 1                    DZA             Algeria       DZ      NY.GDP.PCAP.KD.ZG
# 2                    DZA             Algeria       DZ         NY.GDP.MKTP.KD
# 3                    DZA             Algeria       DZ         NY.GDP.MKTP.CD
# 4                    DZA             Algeria       DZ         NE.CON.TETC.CD
# ...                  ...                 ...      ...                    ...
# 1724                 SSA  Sub-Saharan Africa      NaN      GC.REV.TOTL.GD.ZS
# 1725                 SSA  Sub-Saharan Africa      NaN      GC.XPN.TOTL.GD.ZS
# 1726                 SSA  Sub-Saharan Africa      NaN              BG.CAB.CD
# 1727                 SSA  Sub-Saharan Africa      NaN  BG.WEO.ADB.CAB.GDP.ZS
# 1728                 SSA  Sub-Saharan Africa      NaN         FP.CPI.TOTL.ZG
#
# ...

# %% [markdown]
# # Data Analysis And Cleaning
#
# *To Fully find out information about the given dataset To Find What Exactly we are trying to solve.

# %%
#To get the information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1729 entries, 0 to 1728
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country_and_Regions  1729 non-null   object
#  1   Country              1729 non-null   object
#  2   RegionId             1526 non-null   object
#  3   Indicators           1729 non-null   object
#  4   Indicators_Name      1729 non-null   object
#  5   Scale                1729 non-null   object
#  6   Units                1729 non-null   object
#  7   1980                 1391 non-null   float64
#  8   1981                 1562 non-null   float64
#  9   1982                 1563 non-null   float64
#  10  1983                 1565 non-null   float64
#  11  1984                 1565 non-null   float64
#  12  1985                 1565 non-null   float64
#  13  1986                 1565 non-null   float64
#  14  1987                 1567 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Country_and_Regions', 'Country ', 'RegionId', 'Indicators',
#        'Indicators_Name', 'Scale', 'Units', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020'],
#       dtype='object')

# %%
#To get the quantiles and the description of the dataset

df.describe()
# Out:
#                 1980           1981           1982           1983  \
# count    1391.000000    1562.000000    1563.000000    1565.000000
# mean     5206.961399    4673.101459    4509.660384    4269.458775
# std     25433.338174   24513.764053   24227.432385   22987.550310
# min    -13530.455584  -24831.687809  -32591.088701  -27609.162681
# 25%        13.743778       7.796051       7.759880       7.016619
# 50%        57.340162      37.662311      39.249372      36.573401
# 75%       957.923497     609.219468     591.243915     551.787440
# max    421123.946158  410150.769857  410079.623750  397146.214149
#
#                 1984           1985           1986           1987  \
# count    1565.000000    1565.000000    1565.000000    1567.000000
# mean     4178.829828    4138.623542    4287.405137    4634.993772
# std     22444.928215   22336.079764   23321.361832   25149.999818
# min    -25329.752793  -19745.288630  -28376.688184  -31695.587418
# ...

# %%
#To describe the information about the Indicators in the dataset.Indicators show the type of money acquired in each 
#African country
#This information will assisst in knowing what type of Indicator is largely used. 

df[["Indicators"]].describe()
# Out:
#                Indicators
# count                1729
# unique                 29
# top     NY.GDP.MKTP.KD.ZG
# freq                   61

# %%
#Calculating the sum of the nulls of each column of the African Economic State

df.isnull().sum()
# Out:
# Country_and_Regions      0
# Country                  0
# RegionId               203
# Indicators               0
# Indicators_Name          0
# Scale                    0
# Units                    0
# 1980                   338
# 1981                   167
# 1982                   166
# 1983                   164
# 1984                   164
# 1985                   164
# 1986                   164
# 1987                   162
# 1988                   162
# 1989                   161
# 1990                   105
# 1991                   105
# 1992                    82
# 1993                    79
# 1994                    76
# 1995                    76
# 1996                    76
# 1997                    76
# 1998                    76
# 1999                    76
# 2000                    40
# 2001                    38
# 2002                    20
# 2003                    34
# 2004                    36
# 2005                    36
# 2006                    34
# ...

# %%
#To identify the duplicated rows of the dataset

df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country_and_Regions, Country , RegionId, Indicators, Indicators_Name, Scale, Units, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []
#
# [0 rows x 48 columns]

# %%
#Instead of having Intergers as columns, Have the columns 
#be renamed as floats 

df.rename(columns={'1980':'Year1980',
                   '1981': 'Year1981',
                   '1982': 'Year1982',
                   '1983': 'Year1983',
                   '1984': 'Year1984',
                   '1985': 'Year1985',
                    '1986': 'Year1986',
                    '1987': 'Year1987',
                    '1988': 'Year1988',
                    '1989': 'Year1989',
                    '1990': 'Year1990',
                    '1991': 'Year1991',
                    '1992': 'Year1992',
                    '1993': 'Year1993',
                    '1994': 'Year1994',
                    '1995': 'Year1995',
                    '1996': 'Year1996',
                    '1997': 'Year1997',
                    '1998': 'Year1998',
                    '1999': 'Year1999',
                    '2000': 'Year2000',
                    '2001': 'Year2001',
                    '2002': 'Year2002',
                    '2003': 'Year2003',
                    '2004': 'Year2004',
                    '2005': 'Year2005',
                    '2006': 'Year2006',
                    '2007': 'Year2007',
                    '2008': 'Year2008',
                    '2009': 'Year2009',
                    '2010': 'Year2010',
                    '2011': 'Year2011',
                    '2012': 'Year2012',
                    '2013': 'Year2013',
                    '2014': 'Year2014',
                    '2015': 'Year2015',
                    '2016': 'Year2016',
                    '2017': 'Year2017',
                    '2018': 'Year2018',
                    '2019': 'Year2019'}, inplace=True);
df.head(10)
# Out:
#   Country_and_Regions Country  RegionId         Indicators  \
# 0                 DZA  Algeria       DZ  NY.GDP.MKTP.KD.ZG
# 1                 DZA  Algeria       DZ  NY.GDP.PCAP.KD.ZG
# 2                 DZA  Algeria       DZ     NY.GDP.MKTP.KD
# 3                 DZA  Algeria       DZ     NY.GDP.MKTP.CD
# 4                 DZA  Algeria       DZ     NE.CON.TETC.CD
# 5                 DZA  Algeria       DZ     NE.CON.GOVT.CD
# 6                 DZA  Algeria       DZ     NE.CON.PETC.CD
# 7                 DZA  Algeria       DZ     NE.GDI.TOTL.CD
# 8                 DZA  Algeria       DZ     NE.GDI.PVTE.CD
# 9                 DZA  Algeria       DZ      NE.GDI.PUB.CD
#
#                                      Indicators_Name     Scale         Units  \
# 0                         Real GDP growth (annual %)     units    percentage
# 1         Real per Capita GDP Growth Rate (annual %)     units    percentage
# 2      Gross domestic product, (constant prices US$)  millions  U.S. dollars
# ...

# %%
#To get the total number of different floats and intergers

numerics = ["int16", "int32", "int64", "float16", "float32", "float64"]

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 41

# %%
#To Calculate the total number of missing values per column in percentage 

missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)  
missing_percentages
# Out:
# Year1980               0.195489
# RegionId               0.117409
# Year1981               0.096588
# Year1982               0.096009
# Year1983               0.094853
# Year1986               0.094853
# Year1984               0.094853
# Year1985               0.094853
# Year1988               0.093696
# Year1987               0.093696
# Year1989               0.093117
# Year1991               0.060729
# Year1990               0.060729
# Year1992               0.047426
# Year1993               0.045691
# Year1995               0.043956
# Year1996               0.043956
# Year1998               0.043956
# Year1999               0.043956
# Year1994               0.043956
# Year1997               0.043956
# Year2000               0.023135
# Year2009               0.021978
# Year2001               0.021978
# Year2004               0.020821
# Year2010               0.020821
# Year2005               0.020821
# Year2003               0.019665
# Year2006               0.019665
# ...

# %%
 type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
#A bar graph indicating the position of various values in the dataset starting with the ones with the highest number
#missing values 

missing_percentages[missing_percentages != 0].plot(kind= "bar")
plt.rcParams['figure.figsize'] = (15, 20)

# %% [markdown]
# # EXPLORATORY ANALYSIS AND VISUALIZATION

# %%
#Grouping the dataset in terms of Scale and the Important Indicators depending
#on the description of the Year Quantiles ,Semiquantiles and Standard Deviation 

df_indicators=df.groupby(["Scale","Indicators"])
df_indicators.describe()
# Out:
#                                Year1980                              \
#                                   count          mean           std
# Scale    Indicators
# millions BG.CAB.CD                 54.0   -139.178547   1214.037973
#          GC.BAL.CASH.GD.CD         53.0  -1007.498087   2811.825393
#          GC.REV.TOTL.GD.CD         52.0   6661.268221  16659.545571
#          GC.XPN.TOTL.GD.CD         53.0   7543.082003  18854.842088
#          NE.CON.GOVT.CD            57.0   3820.183494   9920.850626
#          NE.CON.PETC.CD            57.0  14445.691833  37477.556865
#          NE.CON.TETC.CD            57.0  18265.875327  47277.416711
#          NE.EXPO.GNFS.CD           57.0   8158.569667  21474.097733
#          NE.GDI.PUB.CD             51.0   1853.334779   4745.137569
#          NE.GDI.PVTE.CD            51.0   3862.084939   9624.812860
#          NE.GDI.TOTL.CD            57.0   6140.407646  16146.187817
# ...

# %%
#To show the unique columns in the Indicators 

Indicators = df['Indicators'].unique()
len(Indicators)
# Out:
# 29

# %%
#Place the Region columns in the representation of bars 

df['RegionId'].value_counts() \
   .head(10) \
   .plot(kind = 'bar', title = "Consumption of top 10 Indicators Acquired")
ax.set_xlabel('The Type of Indicator')
ax.set_ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       1 #Place the Region columns in the representation of bars
#       3 df['RegionId'].value_counts() \
#       4    .head(10) \
#       5    .plot(kind = 'bar', title = "Consumption of top 10 Indicators Acquired")
# ----> 6 ax.set_xlabel('The Type of Indicator')
#       7 ax.set_ylabel('Count')
#
# NameError: name 'ax' is not defined

# %%
#Sum of the total number of null values in each column of the dataset 

df.isnull().sum()
# Out:
# Country_and_Regions      0
# Country                  0
# RegionId               203
# Indicators               0
# Indicators_Name          0
# Scale                    0
# Units                    0
# Year1980               338
# Year1981               167
# Year1982               166
# Year1983               164
# Year1984               164
# Year1985               164
# Year1986               164
# Year1987               162
# Year1988               162
# Year1989               161
# Year1990               105
# Year1991               105
# Year1992                82
# Year1993                79
# Year1994                76
# Year1995                76
# Year1996                76
# Year1997                76
# Year1998                76
# Year1999                76
# Year2000                40
# Year2001                38
# Year2002                20
# Year2003                34
# Year2004                36
# Year2005                36
# Year2006                34
# ...

# %%
#Information on the mostly used indicator

df_PUB = df[(df.Indicators == 'NE.GDI.PUB.CD')]                     
df_PUB
# Out:
#      Country_and_Regions                  Country  RegionId     Indicators  \
# 9                    DZA                   Algeria       DZ  NE.GDI.PUB.CD
# 38                   AGO                    Angola       AO  NE.GDI.PUB.CD
# 67                   BEN                     Benin       BJ  NE.GDI.PUB.CD
# 96                   BWA                  Botswana       BW  NE.GDI.PUB.CD
# 125                  BFA              Burkina Faso       BF  NE.GDI.PUB.CD
# 154                  BDI                   Burundi       BI  NE.GDI.PUB.CD
# 183                  CMR                  Cameroon       CM  NE.GDI.PUB.CD
# 212                  CPV                Cabo Verde       CV  NE.GDI.PUB.CD
# 241                  CAF  Central African Republic       CF  NE.GDI.PUB.CD
# 270                  TCD                      Chad       TD  NE.GDI.PUB.CD
# 299                  COM                   Comoros       KM  NE.GDI.PUB.CD
# ...

# %%
#Distribution plot of the year 2017.

sns.FacetGrid(df_PUB, height=20).map(sns.distplot,"Year2017").add_legend()
# Out:
# /home/winnie/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
#Consumption of more than 100 in the year 2011 where the inidcator was NY.GDP.MKTP.KD

df_Y11 = df[(df.Year2011 >= 100) & (df.Indicators == 'NY.GDP.MKTP.KD')]                   
df_Y11
# Out:
#      Country_and_Regions            Country  RegionId      Indicators  \
# 2                    DZA             Algeria       DZ  NY.GDP.MKTP.KD
# 31                   AGO              Angola       AO  NY.GDP.MKTP.KD
# 60                   BEN               Benin       BJ  NY.GDP.MKTP.KD
# 89                   BWA            Botswana       BW  NY.GDP.MKTP.KD
# 118                  BFA        Burkina Faso       BF  NY.GDP.MKTP.KD
# ...                  ...                 ...      ...             ...
# 1586                EAST         East Africa      NaN  NY.GDP.MKTP.KD
# 1615               NORTH        North Africa      NaN  NY.GDP.MKTP.KD
# 1644               SOUTH     Southern Africa      NaN  NY.GDP.MKTP.KD
# 1673                WEST         West Africa      NaN  NY.GDP.MKTP.KD
# 1702                 SSA  Sub-Saharan Africa      NaN  NY.GDP.MKTP.KD
#
#                                     Indicators_Name     Scale         Units  \
# ...

# %%
Kenyan_indicators = df[(df.RegionId == 'KE')]
Kenyan_indicators = Kenyan_indicators.groupby('Indicators').mean()
Kenyan_indicators
# Out:
# /tmp/ipykernel_3788/1127197328.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Kenyan_indicators = Kenyan_indicators.groupby('Indicators').mean()
#                            Year1980     Year1981     Year1982     Year1983  \
# Indicators
# BG.CAB.CD              -1076.668762  -642.950296  -295.140616   -36.057137
# BG.WEO.ADB.CAB.GDP.ZS    -10.746256    -6.813179    -3.248404    -0.429126
# FP.CPI.TOTL.ZG                  NaN     7.895316    13.817103    11.605585
# GC.BAL.CASH.GD.CD       -546.968966  -504.948341  -390.922795  -259.367225
# GC.BAL.CASH.GD.ZS         -5.459310    -5.350808    -4.302611    -3.086800
# GC.REV.TOTL.GD.CD       1811.549223  1721.554422  1566.749963  1377.209940
# GC.REV.TOTL.GD.ZS         18.081115    18.242871    17.244110    16.390548
# ...

# %%
#Sum of all the Indicators grouped over the years on all of the African Countries in January of 2019. 

df.groupby("Indicators").sum()
# Out:
# /tmp/ipykernel_3788/2020844947.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Indicators").sum()
#                            Year1980      Year1981      Year1982      Year1983  \
# Indicators
# BG.CAB.CD             -7.515642e+03 -8.736865e+04 -8.519256e+04 -5.082121e+04
# BG.WEO.ADB.CAB.GDP.ZS -4.290858e+02 -4.983638e+02 -5.514520e+02 -3.212418e+02
# FP.CPI.TOTL.ZG         0.000000e+00  8.429206e+02  6.779614e+02  7.981604e+02
# GC.BAL.CASH.GD.CD     -5.339740e+04 -9.206303e+04 -1.174933e+05 -9.763050e+04
# GC.BAL.CASH.GD.ZS     -2.973890e+02 -3.612230e+02 -3.993631e+02 -3.428870e+02
# GC.REV.TOTL.GD.CD      3.463859e+05  3.349895e+05  3.265087e+05  3.135025e+05
# GC.REV.TOTL.GD.ZS      1.219045e+03  1.160384e+03  1.215135e+03  1.199403e+03
# ...

# %%
#To find the summary statistics of the loans, bonds and credits the African countries have in millions. 

df.query('Scale == "millions"').describe()
# Out:
#             Year1980       Year1981       Year1982       Year1983  \
# count     767.000000     771.000000     771.000000     772.000000
# mean     9422.616487    9445.266779    9119.956086    8633.585860
# std     33676.813504   34252.116540   33892.565782   32160.486068
# min    -13530.455584  -24831.687809  -32591.088701  -27609.162681
# 25%       104.425280      91.675961      91.704717      81.118694
# 50%       660.953992     630.445340     618.844453     590.562030
# 75%      3722.631236    3589.999466    3583.643557    3194.457215
# max    421123.946158  410150.769857  410079.623750  397146.214149
#
#             Year1984       Year1985       Year1986       Year1987  \
# count     772.000000     772.000000     772.000000     773.000000
# mean     8449.063384    8367.039309    8669.807420    9374.102682
# std     31398.886642   31252.272748   32639.531113   35194.994325
# min    -25329.752793  -19745.288630  -28376.688184  -31695.587418
# ...

# %%
dft = df.set_index("RegionId").T
dft
# Out:
# RegionId                                     DZ  \
# Country_and_Regions                         DZA
# Country                                 Algeria
# Indicators                    NY.GDP.MKTP.KD.ZG
# Indicators_Name      Real GDP growth (annual %)
# Scale                                     units
# Units                                percentage
# Year1980                                    NaN
# Year1981                               3.000005
# Year1982                               6.400001
# Year1983                               5.399997
# Year1984                               5.599997
# Year1985                               5.600001
# Year1986                                   -0.2
# Year1987                              -0.699999
# Year1988                              -1.899998
# Year1989                               4.799998
# Year1990                               1.251756
# Year1991                                   -1.2
# ...

# %%
dft.columns.unique()
# Out:
# Index([    'DZ',     'AO',     'BJ',     'BW',     'BF',     'BI',     'CM',
#            'CV',     'CF',     'TD',     'KM',     'CD',     'CG',     'CI',
#            'DJ',     'EG',     'GQ',     'ER',     'SZ',     'ET',     'GA',
#            'GM',     'GH',     'GN',     'GW',     'KE',     'LS',     'LR',
#            'LY',     'MG',     'MW',     'ML',     'MR',     'MU',     'MA',
#            'MZ',      nan,     'NE',     'NG',     'RW',     'ST',     'SN',
#            'SC',     'SL',     'SO',     'ZA',     'SS',     'SD',     'TZ',
#            'TG',     'TN',     'UG',     'ZM',     'ZW', 'Africa'],
#       dtype='object', name='RegionId')

# %%
df_country = df.RegionId.unique()
df_country
# Out:
# array(['DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM',
#        'CD', 'CG', 'CI', 'DJ', 'EG', 'GQ', 'ER', 'SZ', 'ET', 'GA', 'GM',
#        'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR',
#        'MU', 'MA', 'MZ', nan, 'NE', 'NG', 'RW', 'ST', 'SN', 'SC', 'SL',
#        'SO', 'ZA', 'SS', 'SD', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW',
#        'Africa'], dtype=object)

# %%
#Calculating the average money used in different African countries per Indicator over the years each January from 1980

df_indicatorsmean =  df.groupby('Indicators').mean()
df_indicatorsmean
# Out:
# /tmp/ipykernel_3788/4098635036.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_indicatorsmean =  df.groupby('Indicators').mean()
#                            Year1980      Year1981      Year1982      Year1983  \
# Indicators
# BG.CAB.CD               -139.178547  -1617.937916  -1577.639971   -941.133461
# BG.WEO.ADB.CAB.GDP.ZS     -8.251650     -9.583919    -10.604846     -6.177727
# FP.CPI.TOTL.ZG                  NaN     17.934480     14.124195     16.628341
# GC.BAL.CASH.GD.CD      -1007.498087  -1737.038368  -2216.854556  -1842.084953
# GC.BAL.CASH.GD.ZS         -5.611113     -6.815528     -7.535153     -6.469565
# GC.REV.TOTL.GD.CD       6661.268221   6442.105608   6279.013465   5915.140823
# GC.REV.TOTL.GD.ZS         23.443178     22.315079     23.367979     22.630254
# ...

# %%
#The highest Indicator Used in the Year 2005 in different Regions Beginning with the Highest Values of The Total Amount
#This determines th country and the type of Indicator used At The moment.


highest_Indicator05= df.pivot_table(index=['RegionId', 'Indicators'], values='Year2005', aggfunc='sum').reset_index().sort_values(['Year2005'], ascending = True)
highest_Indicator05.column = ['RegionId', 'Indicators', 'Year2005']
highest_Indicator05.head(50)
# Out:
# /tmp/ipykernel_3788/1475527164.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   highest_Indicator05.column = ['RegionId', 'Indicators', 'Year2005']
#      RegionId         Indicators       Year2005
# 52     Africa     NE.IMP.GNFS.CD -316552.791190
# 1462       ZA     NE.IMP.GNFS.CD  -68805.833319
# 429        EG     NE.IMP.GNFS.CD  -30319.249961
# 400        DZ     NE.IMP.GNFS.CD  -25348.136235
# 835        MA     NE.IMP.GNFS.CD  -22572.714760
# 1067       NG     NE.IMP.GNFS.CD  -21177.700005
# 23         AO     NE.IMP.GNFS.CD  -15144.220834
# 1375       TN     NE.IMP.GNFS.CD  -14625.790042
# 806        LY     NE.IMP.GNFS.CD  -14281.054961
# 409        EG  GC.BAL.CASH.GD.CD   -8762.021948
# 1154       SD     NE.IMP.GNFS.CD   -8606.277420
# 1439       ZA          BG.CAB.CD   -8569.298967
# 284        CI     NE.IMP.GNFS.CD   -7208.215077
# ...

# %%
#Group the Indicators and the Region to identify the country using the highest amount depending on the Indicator    

df.groupby(["Indicators", "RegionId"]).aggregate(lambda x :','.join(map(str,x)))
# Out:
#                            Country_and_Regions      Country   \
# Indicators        RegionId
# BG.CAB.CD         AO                       AGO        Angola
#                   Africa                   AFR        Africa
#                   BF                       BFA  Burkina Faso
#                   BI                       BDI       Burundi
#                   BJ                       BEN         Benin
# ...                                        ...           ...
# NY.GDP.PCAP.KD.ZG TZ                       TZA      Tanzania
#                   UG                       UGA        Uganda
#                   ZA                       ZAF  South Africa
#                   ZM                       ZMB        Zambia
#                   ZW                       ZWE      Zimbabwe
#
#                                                          Indicators_Name  \
# Indicators        RegionId
# BG.CAB.CD         AO        Current account balance (Net, BoP, cur. US$)
# ...

# %%
#The total average amount of money in general used per indicator in the Year 2005 By different African Countries Over 
#The period 

Indicators_05 = df.groupby('Indicators')['Year2005'].sum()
Indicators_05
# Out:
# Indicators
# BG.CAB.CD                1.781465e+05
# BG.WEO.ADB.CAB.GDP.ZS   -1.465685e+02
# FP.CPI.TOTL.ZG           4.623383e+02
# GC.BAL.CASH.GD.CD        4.735181e+04
# GC.BAL.CASH.GD.ZS        1.846831e+01
# GC.REV.TOTL.GD.CD        1.044827e+06
# GC.REV.TOTL.GD.ZS        1.481317e+03
# GC.XPN.TOTL.GD.CD        9.964998e+05
# GC.XPN.TOTL.GD.ZS        1.440343e+03
# NE.CON.GOVT.CD           5.305958e+05
# NE.CON.GOVT.ZS           8.469509e+02
# NE.CON.PETC.CD           2.487796e+06
# NE.CON.PETC.ZS           4.031539e+03
# NE.CON.TETC.CD           3.018392e+06
# NE.CON.TETC.ZS           4.878490e+03
# NE.EXPO.GNFS.CD          1.300612e+06
# NE.EXPO.GNFS.ZS          1.988632e+03
# NE.GDI.PUB.CD            2.739256e+05
# NE.GDI.PUB.ZS            3.996198e+02
# NE.GDI.PVTE.CD           4.759021e+05
# NE.GDI.PVTE.ZS           9.048958e+02
# NE.GDI.TOTL.CD           7.498277e+05
# NE.GDI.TOTL.ZS           1.304227e+03
# NE.IMP.GNFS.CD          -1.159064e+06
# ...

# %%
Indicators_05.head(15).plot(kind='barh',
        x='Year2005',
        y='Indicators',
        title='Indicators against year 2005'           
       )
plt.rcParams['figure.figsize']= (5, 5)
plt.show()

# %%
Indicators_05.head(15).plot(kind='line',
        x='Year2005',
        y='Indicators',
        title='The show of different Indicators in the Year 2005'           
       )
plt.rcParams['figure.figsize']= (10, 20)
plt.show()

# %%
dft.columns
# Out:
# Index(['DZ', 'DZ', 'DZ', 'DZ', 'DZ', 'DZ', 'DZ', 'DZ', 'DZ', 'DZ',
#        ...
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan],
#       dtype='object', name='RegionId', length=1729)

# %%
data = df_indicatorsmean
data
# Out:
#                            Year1980      Year1981      Year1982      Year1983  \
# Indicators
# BG.CAB.CD               -139.178547  -1617.937916  -1577.639971   -941.133461
# BG.WEO.ADB.CAB.GDP.ZS     -8.251650     -9.583919    -10.604846     -6.177727
# FP.CPI.TOTL.ZG                  NaN     17.934480     14.124195     16.628341
# GC.BAL.CASH.GD.CD      -1007.498087  -1737.038368  -2216.854556  -1842.084953
# GC.BAL.CASH.GD.ZS         -5.611113     -6.815528     -7.535153     -6.469565
# GC.REV.TOTL.GD.CD       6661.268221   6442.105608   6279.013465   5915.140823
# GC.REV.TOTL.GD.ZS         23.443178     22.315079     23.367979     22.630254
# GC.XPN.TOTL.GD.CD       7543.082003   8057.594813   8377.396069   7757.225776
# GC.XPN.TOTL.GD.ZS         28.611967     28.709568     30.462227     29.099819
# NE.CON.GOVT.CD          3820.183494   4075.604040   4011.651266   3936.674286
# NE.CON.GOVT.ZS            16.430259     16.839731     16.730334     16.638464
# ...

# %%
data.T = set_index(data).T
data.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.T = set_index(data).T
#       2 data.T
#
# NameError: name 'set_index' is not defined

# %%
#Calculating the different loans , bonds and credits that were given to Kenya over the years .

data_KE = df.query('RegionId == "KE"').head(20) 
data_KE = data_KE.groupby(["Indicators", "Scale"]).aggregate(lambda x: ','.join(map(str, x)))
data_KE
# Out:
#                            Country_and_Regions Country  RegionId  \
# Indicators        Scale
# NE.CON.GOVT.CD    millions                 KEN    Kenya       KE
# NE.CON.GOVT.ZS    units                    KEN    Kenya       KE
# NE.CON.PETC.CD    millions                 KEN    Kenya       KE
# NE.CON.PETC.ZS    units                    KEN    Kenya       KE
# NE.CON.TETC.CD    millions                 KEN    Kenya       KE
# NE.CON.TETC.ZS    units                    KEN    Kenya       KE
# NE.EXPO.GNFS.CD   millions                 KEN    Kenya       KE
# NE.EXPO.GNFS.ZS   units                    KEN    Kenya       KE
# NE.GDI.PUB.CD     millions                 KEN    Kenya       KE
# NE.GDI.PUB.ZS     units                    KEN    Kenya       KE
# NE.GDI.PVTE.CD    millions                 KEN    Kenya       KE
# NE.GDI.PVTE.ZS    units                    KEN    Kenya       KE
# NE.GDI.TOTL.CD    millions                 KEN    Kenya       KE
# ...

# %%
KE_value = data_KE.query('Scale == "millions"').describe()
KE_value
# Out:
#        Country_and_Regions Country  RegionId  \
# count                   10       10       10
# unique                   1        1        1
# top                    KEN    Kenya       KE
# freq                    10       10       10
#
#                                           Indicators_Name         Units  \
# count                                                  10            10
# unique                                                 10             1
# top     General government final consumption expenditu...  U.S. dollars
# freq                                                    1            10
#
#                 Year1980          Year1981          Year1982  \
# count                 10                10                10
# unique                10                10                10
# top     1439.31624392367  1273.27991157778  1184.73215348416
# freq                   1                 1                 1
#
# ...

# %%
df['Indicators'].value_counts() \
   .head(10) \
   .plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (5, 6)
plt.show()

# %%
sns.pairplot(df, vars=['Year1980', 'Year1990', 
                       'Year2000', 'Year2010'], hue='Scale')
plt.show()

# %%
data[['Year1980', 'Year1990',
     'Year2000', 'Year2010']].dropna().corr()
# Out:
#           Year1980  Year1990  Year2000  Year2010
# Year1980  1.000000  0.996813  0.991859  0.958505
# Year1990  0.996813  1.000000  0.995937  0.957934
# Year2000  0.991859  0.995937  1.000000  0.943365
# Year2010  0.958505  0.957934  0.943365  1.000000

# %%
kc_tax = df.loc[(df.Indicators == "NY.GDP.MKTP.KD") &
                    (df.Year2019 > 1.5)
                    , :]
kc_tax.head()
# Out:
#     Country_and_Regions      Country  RegionId      Indicators  \
# 2                   DZA       Algeria       DZ  NY.GDP.MKTP.KD
# 31                  AGO        Angola       AO  NY.GDP.MKTP.KD
# 60                  BEN         Benin       BJ  NY.GDP.MKTP.KD
# 89                  BWA      Botswana       BW  NY.GDP.MKTP.KD
# 118                 BFA  Burkina Faso       BF  NY.GDP.MKTP.KD
#
#                                    Indicators_Name     Scale         Units  \
# 2    Gross domestic product, (constant prices US$)  millions  U.S. dollars
# 31   Gross domestic product, (constant prices US$)  millions  U.S. dollars
# 60   Gross domestic product, (constant prices US$)  millions  U.S. dollars
# 89   Gross domestic product, (constant prices US$)  millions  U.S. dollars
# 118  Gross domestic product, (constant prices US$)  millions  U.S. dollars
#
#          Year1980      Year1981      Year1982  ...      Year2011  \
# 2    34512.329728  35547.701326  37822.754445  ...  82306.010060
# ...

# %%
ax = df.plot.hexbin(x='Year1980', y='Year2019',
gridsize=30, sharex=False, figsize=(5, 4))
ax.set_xlabel('Regions Involved')
ax.set_ylabel('Data in the 1980')
# Out:
# Text(0, 0.5, 'Data in the 1980')

# %%
top_10_countries = df[df.RegionId == "KE"].value_counts().sort_values(ascending=False)
top_10_countries.head(10)
# Out:
# Country_and_Regions  Country   RegionId  Indicators             Indicators_Name                                                        Scale     Units              Year1980      Year1981      Year1982      Year1983      Year1984      Year1985      Year1986      Year1987      Year1988      Year1989      Year1990      Year1991      Year1992      Year1993      Year1994      Year1995      Year1996      Year1997      Year1998      Year1999      Year2000      Year2001      Year2002      Year2003      Year2004      Year2005      Year2006      Year2007      Year2008      Year2009      Year2010       Year2011      Year2012       Year2013       Year2014       Year2015       Year2016       Year2017       Year2018       Year2019       2020
# ...

# %%
womenOlympics = df[(df.Indicators == 'NE.CON.GOVT.ZS')]
womenOlympics
# Out:
#      Country_and_Regions                  Country  RegionId      Indicators  \
# 13                   DZA                   Algeria       DZ  NE.CON.GOVT.ZS
# 42                   AGO                    Angola       AO  NE.CON.GOVT.ZS
# 71                   BEN                     Benin       BJ  NE.CON.GOVT.ZS
# 100                  BWA                  Botswana       BW  NE.CON.GOVT.ZS
# 129                  BFA              Burkina Faso       BF  NE.CON.GOVT.ZS
# 158                  BDI                   Burundi       BI  NE.CON.GOVT.ZS
# 187                  CMR                  Cameroon       CM  NE.CON.GOVT.ZS
# 216                  CPV                Cabo Verde       CV  NE.CON.GOVT.ZS
# 245                  CAF  Central African Republic       CF  NE.CON.GOVT.ZS
# 274                  TCD                      Chad       TD  NE.CON.GOVT.ZS
# 303                  COM                   Comoros       KM  NE.CON.GOVT.ZS
# ...

# %%
import pandas as pd
import seaborn as sns
sample_data = pd.DataFrame({
'income': df.sample(1000),
'type': 'Data',
})
sample_mean_05 = pd.DataFrame({
'income': [loans_income.sample(5).mean() for _ in range(1000)],
'type': 'Mean of 5',
})
sample_mean_20 = pd.DataFrame({
'income': [loans_income.sample(20).mean() for _ in range(1000)],
'type': 'Mean of 20',
})
results = pd.concat([sample_data, sample_mean_05, sample_mean_20])
g = sns.FacetGrid(results, col='type', col_wrap=1, height=2, aspect=2)
g.map(plt.hist, 'income', range=[0, 200000], bins=40)
g.set_axis_labels('Income', 'Count')
g.set_titles('{col_name}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 sample_data = pd.DataFrame({
#       4 'income': df.sample(1000),
#       5 'type': 'Data',
#       6 })
#       7 sample_mean_05 = pd.DataFrame({
#       8 'income': [loans_income.sample(5).mean() for _ in range(1000)],
#       9 'type': 'Mean of 5',
#      10 })
#      11 sample_mean_20 = pd.DataFrame({
#      12 'income': [loans_income.sample(20).mean() for _ in range(1000)],
#      13 'type': 'Mean of 20',
#      14 })
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:662, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     656     mgr = self._init_mgr(
#     657         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     658     )
#     660 elif isinstance(data, dict):
# ...
